# %% [markdown]
# # Instructions
#
# For Part A, you need to scrape IMDB web page to find out top movies sorted by user votes. For each movie, you need to pull :
# - movie_id
# - rank
# - title
# - runtime
# - year
# - rating
# - votes
#
# The URL of an page that include movies released between 2018 and 2020 sorted by number of votes is:
#
# https://www.imdb.com/search/title/?title_type=feature&release_date=2018-01-01,2020-12-31&sort=num_votes,desc
#
# Please click the URL and investigate how you can pull movie_id, rank, title,... from the webpage.
#
#
# **You need to write code after where I have <span style="color:red">'''  Your code here ...    '''.</span>**
#
# ***
# Now let’s look at the read_m_from_html_string(url, num_of_m=50) function in detail. The parameter “num_of_m” in the function def read_m_from_html_string(url, num_of_m=50)
#   represents the top number of movies you want to retrieve. For example, read_m_from_html_string(url,500) means that we want to extract top 500 movies released between, sorted by users' votes.
#
# This function returns a list of dictionaries. Each dictionary represents one of the top movies, which could look like the following:
#
# {
#
#     'movie_id': 'tt7286456',
#     'rank': '1.',
#     'title': 'Joker',
#     'runtime': 2h 2m,
#     'year': '2019',
#     'rating': '8.4',
#     'votes': '1,421,777',
# }
#
#
# After you implement “read_m_from_html_string”, which will return a list of top movies, you need to export the movies list to a csv file.
#
#
# ***
#
# After you done with scraping the needed data, you should clean and transform it as needed to make it ready for enriching the given "Movies.csv" dataset.
# ***
#
# Finaly, export the enriched dataset to a CSV file:
# Use the following naming convention: Project_3_PartA_Lastname.csv

# %%
import warnings
warnings.filterwarnings('ignore')
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# ***
#
# ## read_m_from_html_string
#
# Inside this function, you need to write your code to pull the movies information from the provided Movies 500 HTML String text file.
#
# For each movie, you need to pull :
# - movie_id
# - rank
# - title
# - runtime
# - year
# - rating
# - votes
#
# To give examples on how to pull data from the web bage html string, I have included the code to pull the movie_id.
# You need to inculde your code to pull the other needed movie information (title, rank, year, ......). You should have no missing values for each of the collected data.
#
# The URL of an page that include movies released between 2018 and 2020 sorted by number of votes is:
#
# https://www.imdb.com/search/title/?title_type=feature&release_date=2018-01-01,2020-12-31&sort=num_votes,desc
#
# Please click the URL and investigate how you can pull movie_id, rank, title,... from the webpage using the Inspect option.

# %%
# This function, read a number of movies from a url html string. The default value is 50
def read_m_from_html_string(url, num_of_m=50):
    
    print(url)
    
    with open('TopVoted_500_Movies_HTML.txt', 'r', encoding="utf8") as file:
        html_string = file.read()   # to read the hmtl file as a string
        # I have included the Movies 500 HTML String.txt file in the project folder. Please take a look.
    
    # create a soup object
    soup = BeautifulSoup(html_string, "html.parser")
    
    '''
    Click the URL and investigate how you can pull movie_id, rank, title,... from the webpage.
    To investigate the html of a web page , For example:
    URL: https://www.imdb.com/search/title/?title_type=feature&release_date=2018-01-01,2020-12-31&sort=num_votes,desc
    Right-click anywhere on the webpage, and at the very bottom of the menu that pops up, 
    you will see "Inspect", Click on it.
    '''
    '''
    Fetching a div that includes all the movies. This can be done by using find and find_all functions.
    for example, find_all('div') will give you all divs on the page. Actually, 
    this find or find_all function can have two parameters,
    in the code below 'div' is the tag name and 'ipc-page-grid__item ipc-page-grid__item--span-2' is an attribute 
    value of the tag. You can also do movie_list = soup.find('div', 'ipc-page-grid__item ipc-page-grid__item--span-2'). 
    Here you explicitly say: I want to find a div with 
    attribute class = 'ipc-page-grid__item ipc-page-grid__item--span-2'.
    
    Since on each imdb page, there's only one div with class = 'lister-list', we can use find rather than find_all. 
    Find_all will return a list of div tags, while find() will return only one div.
   '''     
    movie_list = soup.find('div', 'ipc-page-grid__item ipc-page-grid__item--span-2') 
    # this div contains all the listed movies in the requested html web page string.
    
    list_movies = [] # initialize the function return value, which is a list of movies. 
                     # This list will contains the scraped data transformed to a structured format.
    
    # Using count track the number of movies processed. now it's 0 - No movie has been processed yet.
    count = 0
    
    # each movie listed in a div with attribute value 'ipc-metadata-list-summary-item'.
    divs=  movie_list.find_all('li','ipc-metadata-list-summary-item') # To find all the listed movies in the page.
    for d in divs:
        dict_each_movie = {}  # initialize the movie dictionary to store the movie information.

        # Pulling the movie_id
        try:
            movie_id= d.find('a', 'ipc-title-link-wrapper').attrs['href']
            movie_id= movie_id[7:16]
            
        except:
            movie_id=""
        finally:
            dict_each_movie["movie_id"] = movie_id
            print(movie_id)
            
        # Pulling the rank
        '''  Your code here ...    '''

        try:
            rank = d.find('h3','ipc-title__text').text
            rank= rank.split('. ')[0]
        
        except:
            rank=""
        finally:
            dict_each_movie["rank"] = rank
            print (rank)        
        
        
        
        

        # Pulling the title
        '''  Your code here ...    '''

        try:
            title= d.find('h3','ipc-title__text').text
            title =title.split('. ')[1]
        except:
            title=""
        finally:
            dict_each_movie["title"] = title
            print (title)        
        
        
        
     
        
        # Pulling the runtime
        '''  Your code here ...    '''
      
        try:
            runtime= d.find_all('span','sc-479faa3c-8 bNrEFi dli-title-metadata-item')
            run_time=''
            for r in runtime:
                run_time=run_time + ',' + r.text
            run_time=run_time.split(',')[2]
            
        except:
            run_time=""
        finally:
            dict_each_movie["run_time"] = run_time
            print (run_time)        
        
        
        
        # Pulling the year
        '''  Your code here ...    ''' 
        
        try:
            release_year= d.find_all('span','sc-479faa3c-8 bNrEFi dli-title-metadata-item')
            year=''
            for y in release_year:
                year=year + ',' + y.text
            year=year.split(',')[1]
            
        except:
            year=""
        finally:
            dict_each_movie["year"] = year
            print (year)        
        
        
                
        # Pulling the rating
          # the rating out of 10
        '''  Your code here ...    '''     
 
        try:
            rating = d.find('span','ipc-rating-star ipc-rating-star--base ipc-rating-star--imdb ratingGroup--imdb-rating').text
            rating = rating.split('(')[0]
            rating=rating[:-1]
            
        except:
            rating=""
        finally:
            dict_each_movie["rating"] = rating
            print (rating)        
        
        
        
        
        # Pulling the votes
        '''  Your code here ...    '''
        try:
            votes = d.find('div','sc-21df249b-0 jmcDPS').text
            votes = votes.split('Votes')[1]
            # votes = votes[:-1]
        except:
            votes=""
        finally:
            dict_each_movie["votes"] = votes
            print (votes)  
            
        
        
        list_movies.append(dict_each_movie)  # To add the movie information to the movies list.

        count +=1
        print('===============================')
        print()
        if count == num_of_m:
            break # to exit from the loop.

    return list_movies

# %% [markdown]
# ###  Call statement to scrap the TopVoted 500 movies
# ##### read_m_from_html_string(url,500)

# %%
url = "https://www.imdb.com/search/title/?title_type=feature&release_date=
# tt4648786
# 488
# Harriet
# 2h 5m
# 2019
# 6.7
# 29,801
# ===============================
#
# tt9691136
# 489
# Shadow in the Cloud
# 1h 23m
# 2020
# 5.0
# 29,775
# ===============================
#
# tt6288124
# 490
# Don't Worry, He Won't Get Far on Foot
# 1h 54m
# 2018
# 6.8
# 29,685
# ===============================
#
# tt2126357
# 491
# Second Act
# 1h 43m
# 2018
# 5.8
# 29,655
# ===============================
#
# tt6527426
# 492
# Zero
# 2h 44m
# 2018
# 5.2
# 29,653
# ===============================
#
# tt9252468
# 493
# Mosul
# 1h 41m
# 2019
# 7.1
# 29,652
# ===============================
#
# tt1138238
# 494
# The Dissident
# 1h 59m
# 2020
# 7.8
# 29,583
# ===============================
#
# tt3152592
# 495
# Scoob!
# 1h 33m
# 2020
# 5.6
# 29,336
# ===============================
#
# tt9072352
# 496
# Relic
# 1h 29m
# 2020
# 6.0
# 29,282
# ===============================
#
# tt1006569
# 497
# Antebellum
# 1h 45m
# 2020
# 5.8
# 29,199
# ===============================
#
# tt8652728
# 498
# Waves
# 2h 15m
# 2019
# 7.5
# 29,103
# ===============================
#
# tt7748244
# 499
# Mortal World
# 1h 47m
# 2018
# 7.6
# 29,052
# ===============================
#
# tt6768578
# 500
# Dogman
# 1h 43m
# 2018
# 7.2
# 28,823
# ===============================
# [{'movie_id': 'tt7286456',
#   'rank': '1',
#   'title': 'Joker',
#   'run_time': '2h 2m',
#   'year': '2019',
#   'rating': '8.4',
#   'votes': '1,422,218'},
#  {'movie_id': 'tt4154796',
#   'rank': '2',
#   'title': 'Avengers: Endgame',
#   'run_time': '3h 1m',
#   'year': '2019',
#   'rating': '8.4',
#   'votes': '1,227,564'},
#  {'movie_id': 'tt4154756',
#   'rank': '3',
#   'title': 'Avengers: Infinity War',
#   'run_time': '2h 29m',
#   'year': '2018',
#   'rating': '8.4',
#   'votes': '1,167,536'},
#  {'movie_id': 'tt6751668',
#   'rank': '4',
#   'title': 'Parasite',
#   'run_time': '2h 12m',
#   'year': '2019',
#   'rating': '8.5',
#   'votes': '903,939'},
#  {'movie_id': 'tt1825683',
#   'rank': '5',
#   'title': 'Black Panther',
#   'run_time': '2h 14m',
#   'year': '2018',
#   'rating': '7.3',
#   'votes': '820,837'},
#  {'movie_id': 'tt7131622',
#   'rank': '6',
#   'title': 'Once Upon a Time in Hollywood',
#   'run_time': '2h 41m',
#   'year': '2019',
#   'rating': '7.6',
#   'votes': '809,786'},
#  {'movie_id': 'tt8946378',
#   'rank': '7',
#   'title': 'Knives Out',
#   'run_time': '2h 10m',
#   'year': '2019',
#   'rating': '7.9',
#   'votes': '747,547'},
#  {'movie_id': 'tt8579674',
#   'rank': '8',
#   'title': '1917',
#   'run_time': '1h 59m',
#   'year': '2019',
#   'rating': '8.2',
#   'votes': '650,257'},
#  {'movie_id': 'tt4633694',
#   'rank': '9',
#   'title': 'Spider-Man: Into the Spider-Verse',
#   'run_time': '1h 57m',
#   'year': '2018',
#   'rating': '8.4',
#   'votes': '641,118'},
#  {'movie_id': 'tt5463162',
#   'rank': '10',
#   'title': 'Deadpool 2',
#   'run_time': '1h 59m',
#   'year': '2018',
#   'rating': '7.6',
#   'votes': '624,815'},
#  {'movie_id': 'tt4154664',
#   'rank': '11',
#   'title': 'Captain Marvel',
#   'run_time': '2h 3m',
#   'year': '2019',
#   'rating': '6.8',
#   'votes': '597,379'},
#  {'movie_id': 'tt1727824',
#   'rank': '12',
#   'title': 'Bohemian Rhapsody',
#   'run_time': '2h 14m',
#   'year': '2018',
#   'rating': '7.9',
#   'votes': '574,079'},
#  {'movie_id': 'tt6723592',
#   'rank': '13',
#   'title': 'Tenet',
#   'run_time': '2h 30m',
#   'year': '2020',
#   'rating': '7.3',
#   'votes': '568,337'},
#  {'movie_id': 'tt6644200',
#   'rank': '14',
#   'title': 'A Quiet Place',
#   'run_time': '1h 30m',
#   'year': '2018',
#   'rating': '7.5',
#   'votes': '567,953'},
#  {'movie_id': 'tt6966692',
#   'rank': '15',
#   'title': 'Green Book',
#   'run_time': '2h 10m',
#   'year': '2018',
#   'rating': '8.2',
#   'votes': '542,702'},
#  {'movie_id': 'tt6320628',
#   'rank': '16',
#   'title': 'Spider-Man: Far from Home',
#   'run_time': '2h 9m',
#   'year': '2019',
#   'rating': '7.4',
#   'votes': '537,741'},
#  {'movie_id': 'tt1270797',
#   'rank': '17',
#   'title': 'Venom',
#   'run_time': '1h 52m',
#   'year': '2018',
#   'rating': '6.6',
#   'votes': '523,643'},
#  {'movie_id': 'tt1477834',
#   'rank': '18',
#   'title': 'Aquaman',
#   'run_time': '2h 23m',
#   'year': '2018',
#   'rating': '6.8',
#   'votes': '505,411'},
#  {'movie_id': 'tt2527338',
#   'rank': '19',
#   'title': 'Star Wars: Episode IX - The Rise of Skywalker',
#   'run_time': '2h 21m',
#   'year': '2019',
#   'rating': '6.4',
#   'votes': '480,882'},
#  {'movie_id': 'tt1677720',
#   'rank': '20',
#   'title': 'Ready Player One',
#   'run_time': '2h 20m',
#   'year': '2018',
#   'rating': '7.4',
#   'votes': '468,943'},
#  {'movie_id': 'tt1950186',
#   'rank': '21',
#   'title': 'Ford v Ferrari',
#   'run_time': '2h 32m',
#   'year': '2019',
#   'rating': '8.1',
#   'votes': '444,406'},
#  {'movie_id': 'tt5095030',
#   'rank': '22',
#   'title': 'Ant-Man and the Wasp',
#   'run_time': '1h 58m',
#   'year': '2018',
#   'rating': '7.0',
#   'votes': '438,666'},
#  {'movie_id': 'tt2584384',
#   'rank': '23',
#   'title': 'Jojo Rabbit',
#   'run_time': '1h 48m',
#   'year': '2019',
#   'rating': '7.9',
#   'votes': '426,395'},
#  {'movie_id': 'tt1302006',
#   'rank': '24',
#   'title': 'The Irishman',
#   'run_time': '3h 29m',
#   'year': '2019',
#   'rating': '7.8',
#   'votes': '418,772'},
#  {'movie_id': 'tt6146586',
#   'rank': '25',
#   'title': 'John Wick: Chapter 3 - Parabellum',
#   'run_time': '2h 10m',
#   'year': '2019',
#   'rating': '7.4',
#   'votes': '411,173'},
#  {'movie_id': 'tt1517451',
#   'rank': '26',
#   'title': 'A Star Is Born',
#   'run_time': '2h 16m',
#   'year': '2018',
#   'rating': '7.6',
#   'votes': '408,433'},
#  {'movie_id': 'tt8772262',
#   'rank': '27',
#   'title': 'Midsommar',
#   'run_time': '2h 28m',
#   'year': '2019',
#   'rating': '7.1',
#   'votes': '378,718'},
#  {'movie_id': 'tt0448115',
#   'rank': '28',
#   'title': 'Shazam!',
#   'run_time': '2h 12m',
#   'year': '2019',
#   'rating': '7.0',
#   'votes': '375,801'},
#  {'movie_id': 'tt8367814',
#   'rank': '29',
#   'title': 'The Gentlemen',
#   'run_time': '1h 53m',
#   'year': '2019',
#   'rating': '7.8',
#   'votes': '375,607'},
#  {'movie_id': 'tt2737304',
#   'rank': '30',
#   'title': 'Bird Box',
#   'run_time': '2h 4m',
#   'year': '2018',
#   'rating': '6.6',
#   'votes': '375,423'},
#  {'movie_id': 'tt3778644',
#   'rank': '31',
#   'title': 'Solo: A Star Wars Story',
#   'run_time': '2h 15m',
#   'year': '2018',
#   'rating': '6.9',
#   'votes': '370,847'},
#  {'movie_id': 'tt4912910',
#   'rank': '32',
#   'title': 'Mission: Impossible - Fallout',
#   'run_time': '2h 27m',
#   'year': '2018',
#   'rating': '7.7',
#   'votes': '368,539'},
#  {'movie_id': 'tt2948372',
#   'rank': '33',
#   'title': 'Soul',
#   'run_time': '1h 40m',
#   'year': '2020',
#   'rating': '8.0',
#   'votes': '362,437'},
#  {'movie_id': 'tt7784604',
#   'rank': '34',
#   'title': 'Hereditary',
#   'run_time': '2h 7m',
# ...
#   'title': 'Everybody Knows',
#   'run_time': '2h 13m',
#   'year': '2018',
#   'rating': '6.9',
#   'votes': '37,446'},
#  {'movie_id': 'tt8108202',
#   'rank': '399',
#   'title': 'Stree',
#   'run_time': '2h 8m',
#   'year': '2018',
#   'rating': '7.5',
#   'votes': '37,422'},
#  {'movie_id': 'tt4669788',
#   'rank': '400',
#   'title': 'On the Basis of Sex',
#   'run_time': '2h',
#   'year': '2018',
#   'rating': '7.1',
#   'votes': '37,411'},
#  {'movie_id': 'tt5690360',
#   'rank': '401',
#   'title': 'Slender Man',
#   'run_time': '1h 33m',
#   'year': '2018',
#   'rating': '3.2',
#   'votes': '37,325'},
#  {'movie_id': 'tt4761916',
#   'rank': '402',
#   'title': 'Unfriended: Dark Web',
#   'run_time': '1h 32m',
#   'year': '2018',
#   'rating': '6.0',
#   'votes': '37,277'},
#  {'movie_id': 'tt8633462',
#   'rank': '403',
#   'title': 'Quo Vadis, Aida?',
#   'run_time': '1h 41m',
#   'year': '2020',
#   'rating': '8.0',
#   'votes': '37,184'},
#  {'movie_id': 'tt2639336',
#   'rank': '404',
#   'title': 'Greta',
#   'run_time': '1h 38m',
#   'year': '2018',
#   'rating': '6.0',
#   'votes': '37,086'},
#  {'movie_id': 'tt5198068',
#   'rank': '405',
#   'title': 'Wolfwalkers',
#   'run_time': '1h 43m',
#   'year': '2020',
#   'rating': '8.0',
#   'votes': '37,073'},
#  {'movie_id': 'tt3907584',
#   'rank': '406',
#   'title': 'All the Bright Places',
#   'run_time': '1h 47m',
#   'year': '2020',
#   'rating': '6.6',
#   'votes': '36,961'},
#  {'movie_id': 'tt7725596',
#   'rank': '407',
#   'title': 'Badhaai Ho',
#   'run_time': '2h 4m',
#   'year': '2018',
#   'rating': '7.9',
#   'votes': '36,858'},
#  {'movie_id': 'tt1000300',
#   'rank': '408',
#   'title': 'The Rental',
#   'run_time': '1h 28m',
#   'year': '2020',
#   'rating': '5.7',
#   'votes': '36,852'},
#  {'movie_id': 'tt7280898',
#   'rank': '409',
#   'title': '22 July',
#   'run_time': '2h 23m',
#   'year': '2018',
#   'rating': '6.8',
#   'votes': '36,657'},
#  {'movie_id': 'tt1036246',
#   'rank': '410',
#   'title': 'After We Collided',
#   'run_time': '1h 45m',
#   'year': '2020',
#   'rating': '5.0',
#   'votes': '36,645'},
#  {'movie_id': 'tt8850222',
#   'rank': '411',
#   'title': 'Peninsula',
#   'run_time': '1h 56m',
#   'year': '2020',
#   'rating': '5.5',
#   'votes': '36,566'},
#  {'movie_id': 'tt4878482',
#   'rank': '412',
#   'title': "Dumplin'",
#   'run_time': '1h 50m',
#   'year': '2018',
#   'rating': '6.5',
#   'votes': '36,556'},
#  {'movie_id': 'tt7608028',
#   'rank': '413',
#   'title': 'The Open House',
#   'run_time': '1h 34m',
#   'year': '2018',
#   'rating': '3.3',
#   'votes': '36,449'},
#  {'movie_id': 'tt6141246',
#   'rank': '414',
#   'title': 'The Aeronauts',
#   'run_time': '1h 40m',
#   'year': '2019',
#   'rating': '6.6',
#   'votes': '36,427'},
#  {'movie_id': 'tt1478839',
#   'rank': '415',
#   'title': 'The Art of Racing in the Rain',
#   'run_time': '1h 49m',
#   'year': '2019',
#   'rating': '7.5',
#   'votes': '36,418'},
#  {'movie_id': 'tt5867314',
#   'rank': '416',
#   'title': 'The Empty Man',
#   'run_time': '2h 17m',
#   'year': '2020',
#   'rating': '6.2',
#   'votes': '36,312'},
#  {'movie_id': 'tt1072748',
#   'rank': '417',
#   'title': 'Winchester',
#   'run_time': '1h 39m',
#   'year': '2018',
#   'rating': '5.4',
#   'votes': '36,222'},
#  {'movie_id': 'tt9784456',
#   'rank': '418',
#   'title': 'The Kissing Booth 2',
#   'run_time': '2h 14m',
#   'year': '2020',
#   'rating': '5.7',
#   'votes': '36,105'},
#  {'movie_id': 'tt5523010',
#   'rank': '419',
#   'title': 'The Nutcracker and the Four Realms',
#   'run_time': '1h 39m',
#   'year': '2018',
#   'rating': '5.6',
#   'votes': '36,054'},
#  {'movie_id': 'tt1032414',
#   'rank': '420',
#   'title': 'Article 15',
#   'run_time': '2h 10m',
#   'year': '2019',
#   'rating': '8.1',
#   'votes': '35,992'},
#  {'movie_id': 'tt6865690',
#   'rank': '421',
#   'title': 'The Professor',
#   'run_time': '1h 30m',
#   'year': '2018',
#   'rating': '6.7',
#   'votes': '35,943'},
#  {'movie_id': 'tt9398640',
#   'rank': '422',
#   'title': 'Between Two Ferns: The Movie',
#   'run_time': '1h 22m',
#   'year': '2019',
#   'rating': '6.1',
#   'votes': '35,911'},
#  {'movie_id': 'tt3256226',
#   'rank': '423',
#   'title': 'IO',
#   'run_time': '1h 36m',
#   'year': '2019',
#   'rating': '4.8',
#   'votes': '35,891'},
#  {'movie_id': 'tt5935704',
#   'rank': '424',
#   'title': 'Padmaavat',
#   'run_time': '2h 43m',
#   'year': '2018',
#   'rating': '7.0',
#   'votes': '35,759'},
#  {'movie_id': 'tt2076298',
#   'rank': '425',
#   'title': 'Ip Man 4: The Finale',
#   'run_time': '1h 47m',
#   'year': '2019',
#   'rating': '7.0',
#   'votes': '35,754'},
#  {'movie_id': 'tt9806192',
#   'rank': '426',
#   'title': 'I Lost My Body',
#   'run_time': '1h 21m',
#   'year': '2019',
#   'rating': '7.5',
#   'votes': '35,745'},
#  {'movie_id': 'tt8108268',
#   'rank': '427',
#   'title': 'The Tashkent Files',
#   'run_time': '2h 14m',
#   'year': '2019',
#   'rating': '8.1',
#   'votes': '35,668'},
#  {'movie_id': 'tt1052109',
#   'rank': '428',
#   'title': 'The Forgotten Battle',
#   'run_time': '2h 4m',
#   'year': '2020',
#   'rating': '7.1',
#   'votes': '35,653'},
#  {'movie_id': 'tt8108274',
#   'rank': '429',
#   'title': 'Tanhaji: The Unsung Warrior',
#   'run_time': '2h 15m',
#   'year': '2020',
#   'rating': '7.5',
#   'votes': '35,498'},
#  {'movie_id': 'tt7485048',
#   'rank': '430',
#   'title': 'Super 30',
#   'run_time': '2h 34m',
#   'year': '2019',
#   'rating': '7.9',
#   'votes': '35,412'},
#  {'movie_id': 'tt1035062',
#   'rank': '431',
#   'title': 'Gunjan Saxena: The Kargil Girl',
#   'run_time': '1h 52m',
#   'year': '2020',
#   'rating': '5.5',
#   'votes': '35,359'},
#  {'movie_id': 'tt4073790',
#   'rank': '432',
#   'title': 'The Darkest Minds',
#   'run_time': '1h 44m',
#   'year': '2018',
#   'rating': '5.7',
#   'votes': '35,323'},
#  {'movie_id': 'tt9606374',
#   'rank': '433',
#   'title': 'On the Rocks',
#   'run_time': '1h 36m',
#   'year': '2020',
#   'rating': '6.4',
#   'votes': '35,271'},
#  {'movie_id': 'tt8361028',
#   'rank': '434',
#   'title': 'Cam',
#   'run_time': '1h 34m',
#   'year': '2018',
#   'rating': '5.9',
#   'votes': '35,261'},
#  {'movie_id': 'tt7605074',
#   'rank': '435',
#   'title': 'The Wandering Earth',
#   'run_time': '2h 5m',
#   'year': '2019',
#   'rating': '5.9',
#   'votes': '35,189'},
#  {'movie_id': 'tt6802308',
#   'rank': '436',
#   'title': 'The 15:17 to Paris',
#   'run_time': '1h 34m',
#   'year': '2018',
#   'rating': '5.3',
#   'votes': '35,148'},
#  {'movie_id': 'tt7019842',
#   'rank': '437',
#   'title': '96',
#   'run_time': '2h 38m',
#   'year': '2018',
#   'rating': '8.5',
#   'votes': '34,980'},
#  {'movie_id': 'tt4799066',
#   'rank': '438',
#   'title': 'Midnight Sun',
#   'run_time': '1h 31m',
#   'year': '2018',
#   'rating': '6.6',
#   'votes': '34,947'},
#  {'movie_id': 'tt6535880',
#   'rank': '439',
#   'title': 'Haunt',
#   'run_time': '1h 32m',
#   'year': '2019',
#   'rating': '6.3',
#   'votes': '34,710'},
#  {'movie_id': 'tt6513656',
#   'rank': '440',
#   'title': 'Escape Plan 2: Hades',
#   'run_time': '1h 36m',
#   'year': '2018',
#   'rating': '3.9',
#   'votes': '34,404'},
#  {'movie_id': 'tt4068576',
#   'rank': '441',
#   'title': 'The Nightingale',
#   'run_time': '2h 16m',
#   'year': '2018',
#   'rating': '7.3',
#   'votes': '34,343'},
#  {'movie_id': 'tt8722346',
#   'rank': '442',
#   'title': 'Queen & Slim',
#   'run_time': '2h 12m',
#   'year': '2019',
#   'rating': '7.1',
#   'votes': '34,034'},
#  {'movie_id': 'tt1198989',
#   'rank': '443',
#   'title': 'David Attenborough: A Life on Our Planet',
#   'run_time': '1h 23m',
#   'year': '2020',
#   'rating': '8.9',
#   'votes': '33,942'},
#  {'movie_id': 'tt4357394',
#   'rank': '444',
#   'title': 'Tau',
#   'run_time': '1h 37m',
#   'year': '2018',
#   'rating': '5.8',
#   'votes': '33,897'},
#  {'movie_id': 'tt9340860',
#   'rank': '445',
#   'title': 'Let Him Go',
#   'run_time': '1h 53m',
#   'year': '2020',
#   'rating': '6.7',
#   'votes': '33,889'},
#  {'movie_id': 'tt6095472',
#   'rank': '446',
#   'title': 'The Angry Birds Movie 2',
#   'run_time': '1h 37m',
#   'year': '2019',
#   'rating': '6.4',
#   'votes': '33,775'},
#  {'movie_id': 'tt1061292',
#   'rank': '447',
#   'title': 'One Night in Miami...',
#   'run_time': '1h 54m',
#   'year': '2020',
#   'rating': '7.1',
#   'votes': '33,744'},
#  {'movie_id': 'tt1105764',
#   'rank': '448',
#   'title': 'The Christmas Chronicles: Part Two',
#   'run_time': '1h 52m',
#   'year': '2020',
#   'rating': '6.0',
#   'votes': '33,694'},
#  {'movie_id': 'tt8242084',
#   'rank': '449',
#   'title': 'My Spy',
#   'run_time': '1h 39m',
#   'year': '2020',
#   'rating': '6.3',
#   'votes': '33,640'},
#  {'movie_id': 'tt1285009',
#   'rank': '450',
#   'title': 'The Strangers: Prey at Night',
#   'run_time': '1h 25m',
#   'year': '2018',
#   'rating': '5.2',
#   'votes': '33,619'},
#  {'movie_id': 'tt6285944',
#   'rank': '451',
#   'title': 'The Banker',
#   'run_time': '2h',
#   'year': '2020',
#   'rating': '7.3',
#   'votes': '33,612'},
#  {'movie_id': 'tt7547410',
#   'rank': '452',
#   'title': 'Dora and the Lost City of Gold',
#   'run_time': '1h 42m',
#   'year': '2019',
#   'rating': '6.1',
#   'votes': '33,585'},
#  {'movie_id': 'tt5501104',
#   'rank': '453',
#   'title': 'Border',
#   'run_time': '1h 50m',
#   'year': '2018',
#   'rating': '7.0',
#   'votes': '33,411'},
#  {'movie_id': 'tt9086228',
#   'rank': '454',
#   'title': 'Gretel & Hansel',
#   'run_time': '1h 27m',
#   'year': '2020',
#   'rating': '5.5',
#   'votes': '33,221'},
#  {'movie_id': 'tt7098658',
#   'rank': '455',
#   'title': 'Raazi',
#   'run_time': '2h 18m',
#   'year': '2018',
#   'rating': '7.7',
#   'votes': '33,133'},
#  {'movie_id': 'tt4986098',
#   'rank': '456',
#   'title': 'The Titan',
#   'run_time': '1h 37m',
#   'year': '2018',
#   'rating': '4.8',
#   'votes': '33,014'},
#  {'movie_id': 'tt7946422',
#   'rank': '457',
#   'title': 'Prospect',
#   'run_time': '1h 40m',
#   'year': '2018',
#   'rating': '6.3',
#   'votes': '32,910'},
#  {'movie_id': 'tt6269368',
#   'rank': '458',
#   'title': 'The Clovehitch Killer',
#   'run_time': '1h 49m',
#   'year': '2018',
#   'rating': '6.5',
#   'votes': '32,724'},
#  {'movie_id': 'tt3317234',
#   'rank': '459',
#   'title': 'Game Over, Man!',
#   'run_time': '1h 41m',
#   'year': '2018',
#   'rating': '5.4',
#   'votes': '32,640'},
#  {'movie_id': 'tt9477520',
#   'rank': '460',
#   'title': 'Asuran',
#   'run_time': '2h 21m',
#   'year': '2019',
#   'rating': '8.4',
#   'votes': '32,475'},
#  {'movie_id': 'tt6987770',
#   'rank': '461',
#   'title': 'Destination Wedding',
#   'run_time': '1h 27m',
#   'year': '2018',
#   'rating': '6.0',
#   'votes': '32,400'},
#  {'movie_id': 'tt6218358',
#   'rank': '462',
#   'title': 'Calibre',
#   'run_time': '1h 41m',
#   'year': '2018',
#   'rating': '6.8',
#   'votes': '32,359'},
#  {'movie_id': 'tt9196192',
#   'rank': '463',
#   'title': 'Cuties',
#   'run_time': '1h 36m',
#   'year': '2020',
#   'rating': '3.6',
#   'votes': '32,353'},
#  {'movie_id': 'tt7242142',
#   'rank': '464',
#   'title': 'Blindspotting',
#   'run_time': '1h 35m',
#   'year': '2018',
#   'rating': '7.4',
#   'votes': '32,333'},
#  {'movie_id': 'tt7721800',
#   'rank': '465',
#   'title': 'Bharat',
#   'run_time': '2h 30m',
#   'year': '2019',
#   'rating': '4.7',
#   'votes': '32,076'},
#  {'movie_id': 'tt4995776',
#   'rank': '466',
#   'title': 'The Red Sea Diving Resort',
#   'run_time': '2h 9m',
#   'year': '2019',
#   'rating': '6.6',
#   'votes': '31,786'},
#  {'movie_id': 'tt3721964',
#   'rank': '467',
#   'title': 'Gringo',
#   'run_time': '1h 51m',
#   'year': '2018',
#   'rating': '6.1',
#   'votes': '31,711'},
#  {'movie_id': 'tt6436726',
#   'rank': '468',
#   'title': '7500',
#   'run_time': '1h 33m',
#   'year': '2019',
#   'rating': '6.3',
#   'votes': '31,700'},
#  {'movie_id': 'tt6857166',
#   'rank': '469',
#   'title': 'Book Club',
#   'run_time': '1h 44m',
#   'year': '2018',
#   'rating': '6.1',
#   'votes': '31,661'},
#  {'movie_id': 'tt1298789',
#   'rank': '470',
#   'title': 'American Murder: The Family Next Door',
#   'run_time': '1h 23m',
#   'year': '2020',
#   'rating': '7.2',
#   'votes': '31,528'},
#  {'movie_id': 'tt5144174',
#   'rank': '471',
#   'title': 'The Dry',
#   'run_time': '1h 57m',
#   'year': '2020',
#   'rating': '6.8',
#   'votes': '31,257'},
#  {'movie_id': 'tt7137380',
#   'rank': '472',
#   'title': 'Destroyer',
#   'run_time': '2h 1m',
#   'year': '2018',
#   'rating': '6.2',
#   'votes': '31,227'},
#  {'movie_id': 'tt7430722',
#   'rank': '473',
#   'title': 'War',
#   'run_time': '2h 31m',
#   'year': '2019',
#   'rating': '6.5',
#   'votes': '31,139'},
#  {'movie_id': 'tt9354944',
#   'rank': '474',
#   'title': 'Jexi',
#   'run_time': '1h 24m',
#   'year': '2019',
#   'rating': '6.0',
#   'votes': '30,869'},
#  {'movie_id': 'tt5929754',
#   'rank': '475',
#   'title': 'Wildlife',
#   'run_time': '1h 45m',
#   'year': '2018',
#   'rating': '6.8',
#   'votes': '30,761'},
#  {'movie_id': 'tt9573980',
#   'rank': '476',
#   'title': 'Leaving Neverland',
#   'run_time': '4h',
#   'year': '2019',
#   'rating': '7.0',
#   'votes': '30,740'},
#  {'movie_id': 'tt7634968',
#   'rank': '477',
#   'title': 'What Men Want',
#   'run_time': '1h 57m',
#   'year': '2019',
#   'rating': '5.4',
#   'votes': '30,708'},
#  {'movie_id': 'tt7961060',
#   'rank': '478',
#   'title': 'Dragon Ball Super: Broly',
#   'run_time': '1h 40m',
#   'year': '2018',
#   'rating': '7.7',
#   'votes': '30,619'},
#  {'movie_id': 'tt7772582',
#   'rank': '479',
#   'title': 'Never Rarely Sometimes Always',
#   'run_time': '1h 41m',
#   'year': '2020',
#   'rating': '7.4',
#   'votes': '30,506'},
#  {'movie_id': 'tt8954732',
#   'rank': '480',
#   'title': 'The Princess Switch',
#   'run_time': '1h 41m',
#   'year': '2018',
#   'rating': '6.1',
#   'votes': '30,300'},
#  {'movie_id': 'tt8130968',
#   'rank': '481',
#   'title': 'Badla',
#   'run_time': '1h 58m',
#   'year': '2019',
#   'rating': '7.8',
#   'votes': '30,204'},
#  {'movie_id': 'tt1131714',
#   'rank': '482',
#   'title': 'Shiva Baby',
#   'run_time': '1h 17m',
#   'year': '2020',
#   'rating': '7.1',
#   'votes': '30,110'},
#  {'movie_id': 'tt7329656',
#   'rank': '483',
#   'title': '47 Meters Down: Uncaged',
#   'run_time': '1h 30m',
#   'year': '2019',
#   'rating': '5.0',
#   'votes': '30,069'},
#  {'movie_id': 'tt3089630',
#   'rank': '484',
#   'title': 'Artemis Fowl',
#   'run_time': '1h 35m',
#   'year': '2020',
#   'rating': '4.3',
#   'votes': '30,045'},
#  {'movie_id': 'tt2762506',
#   'rank': '485',
#   'title': 'Bacurau',
#   'run_time': '2h 11m',
#   'year': '2019',
#   'rating': '7.3',
#   'votes': '29,959'},
#  {'movie_id': 'tt7149730',
#   'rank': '486',
#   'title': 'The Silencing',
#   'run_time': '1h 33m',
#   'year': '2020',
#   'rating': '6.2',
#   'votes': '29,926'},
#  {'movie_id': 'tt1308728',
#   'rank': '487',
#   'title': 'The Happytime Murders',
#   'run_time': '1h 31m',
#   'year': '2018',
#   'rating': '5.5',
#   'votes': '29,906'},
#  {'movie_id': 'tt4648786',
#   'rank': '488',
#   'title': 'Harriet',
#   'run_time': '2h 5m',
#   'year': '2019',
#   'rating': '6.7',
#   'votes': '29,801'},
#  {'movie_id': 'tt9691136',
#   'rank': '489',
#   'title': 'Shadow in the Cloud',
#   'run_time': '1h 23m',
#   'year': '2020',
#   'rating': '5.0',
#   'votes': '29,775'},
#  {'movie_id': 'tt6288124',
#   'rank': '490',
#   'title': "Don't Worry, He Won't Get Far on Foot",
#   'run_time': '1h 54m',
#   'year': '2018',
#   'rating': '6.8',
#   'votes': '29,685'},
#  {'movie_id': 'tt2126357',
#   'rank': '491',
#   'title': 'Second Act',
#   'run_time': '1h 43m',
#   'year': '2018',
#   'rating': '5.8',
#   'votes': '29,655'},
#  {'movie_id': 'tt6527426',
#   'rank': '492',
#   'title': 'Zero',
#   'run_time': '2h 44m',
#   'year': '2018',
#   'rating': '5.2',
#   'votes': '29,653'},
#  {'movie_id': 'tt9252468',
#   'rank': '493',
#   'title': 'Mosul',
#   'run_time': '1h 41m',
#   'year': '2019',
#   'rating': '7.1',
#   'votes': '29,652'},
#  {'movie_id': 'tt1138238',
#   'rank': '494',
#   'title': 'The Dissident',
#   'run_time': '1h 59m',
#   'year': '2020',
#   'rating': '7.8',
#   'votes': '29,583'},
#  {'movie_id': 'tt3152592',
#   'rank': '495',
#   'title': 'Scoob!',
#   'run_time': '1h 33m',
#   'year': '2020',
#   'rating': '5.6',
#   'votes': '29,336'},
#  {'movie_id': 'tt9072352',
#   'rank': '496',
#   'title': 'Relic',
#   'run_time': '1h 29m',
#   'year': '2020',
#   'rating': '6.0',
#   'votes': '29,282'},
#  {'movie_id': 'tt1006569',
#   'rank': '497',
#   'title': 'Antebellum',
#   'run_time': '1h 45m',
#   'year': '2020',
#   'rating': '5.8',
#   'votes': '29,199'},
#  {'movie_id': 'tt8652728',
#   'rank': '498',
#   'title': 'Waves',
#   'run_time': '2h 15m',
#   'year': '2019',
#   'rating': '7.5',
#   'votes': '29,103'},
#  {'movie_id': 'tt7748244',
#   'rank': '499',
#   'title': 'Mortal World',
#   'run_time': '1h 47m',
#   'year': '2018',
#   'rating': '7.6',
#   'votes': '29,052'},
#  {'movie_id': 'tt6768578',
#   'rank': '500',
#   'title': 'Dogman',
#   'run_time': '1h 43m',
#   'year': '2018',
#   'rating': '7.2',
#   'votes': '28,823'}]

# %%
# to convert the movies list of dicts to dataframe
df_movies = pd.DataFrame(Movies_list)
df_movies
# Out:
#       movie_id rank                   title run_time  year rating      votes
# 0    tt7286456    1                   Joker    2h 2m  2019    8.4  1,422,218
# 1    tt4154796    2       Avengers: Endgame    3h 1m  2019    8.4  1,227,564
# 2    tt4154756    3  Avengers: Infinity War   2h 29m  2018    8.4  1,167,536
# 3    tt6751668    4                Parasite   2h 12m  2019    8.5    903,939
# 4    tt1825683    5           Black Panther   2h 14m  2018    7.3    820,837
# ..         ...  ...                     ...      ...   ...    ...        ...
# 495  tt9072352  496                   Relic   1h 29m  2020    6.0     29,282
# 496  tt1006569  497              Antebellum   1h 45m  2020    5.8     29,199
# 497  tt8652728  498                   Waves   2h 15m  2019    7.5     29,103
# 498  tt7748244  499            Mortal World   1h 47m  2018    7.6     29,052
# 499  tt6768578  500                  Dogman   1h 43m  2018    7.2     28,823
#
# [500 rows x 7 columns]

# %% [markdown]
# ***
# #  To export the colleted movies to IMDb_TopVoted.csv file.

# %%
df_movies.to_csv('IMDb_TopVoted.csv', index = False)

# %% [markdown]
# # Importing the given dataset "Movies.csv" to Pandas DataFrame called df1

# %%
# Importing the movies.csv file to df1 and print the df1.

df1= pd.read_csv('Movies.csv')

# %%
#Find Empty values in ratingCategory and Fill it with 'Not Rated'
df1['ratingCategory'].fillna('Not Rated', inplace=True)

# %%
#Replace 'Unrated' to 'Not Rated' to have uniform data in ratingCategory field
df1['ratingCategory']=df1['ratingCategory'].replace('Unrated','Not Rated')

# %%
#Replace "\N" with "-" to make it more meaningful
df1['genres']=df1['genres'].replace(r"\N","-")

# %%
df1.head
# Out:
# <bound method NDFrame.head of       movie_id                originalTitle  \
# 0    tt7286456                        Joker
# 1    tt4154796            Avengers: Endgame
# 2    tt4154756       Avengers: Infinity War
# 3    tt6751668                     Parasite
# 4    tt1825683                Black Panther
# ..         ...                          ...
# 495  tt9072352                        Relic
# 496  tt1006569  Episode dated 9 August 2005
# 497  tt8652728                        Waves
# 498  tt7748244                 Mortal World
# 499  tt6768578                       Dogman
#
#                                            description ratingCategory  \
# 0    During the 1980s, a failed stand-up comedian i...              R
# 1    After the devastating events of Avengers: Infi...          PG-13
# 2    The Avengers and their allies must be willing ...          PG-13
# 3    Greed and class discrimination threaten the ne...              R
# 4    T'Challa, heir to the hidden but advanced king...          PG-13
# ..                                                 ...            ...
# 495  A daughter, mother and grandmother are haunted...              R
# 496  Successful author Veronica Henley finds hersel...              R
# 497  Traces the journey of a suburban family - led ...              R
# 498  Mermer Family lives a double life working at t...              R
# 499  A timid dog groomer living in a poor suburb se...      Not Rated
#
#                       genres
# 0       Crime,Drama,Thriller
# 1     Action,Adventure,Drama
# 2    Action,Adventure,Sci-Fi
# 3             Drama,Thriller
# 4    Action,Adventure,Sci-Fi
# ..                       ...
# 495     Drama,Horror,Mystery
# 496                     News
# 497      Drama,Romance,Sport
# 498      Action,Comedy,Crime
# 499     Crime,Drama,Thriller
#
# [500 rows x 5 columns]>

# %% [markdown]
# # Import the scraped data from the IMDb_TopVoted.csv file to Pandas DataFrame called df2

# %%
# You need to import the collected dataset "IMDb_TopVoted.csv" and print the df2.
# To handel Latin characters that may contained in the csv file
# with no issue, use  encoding= "ISO-8859-1" with the pd.read_csv()
# Example: df1 = pd.read_csv('thefilename.csv', encoding= "ISO-8859-1") 
# Using encoding= "ISO-8859-1" will avoid Unicode-Decode-Errors.

df2= pd.read_csv("IMDb_TopVoted.csv", encoding= "ISO-8859-1")

# %% [markdown]
# # Data cleansing and transformation for df2.

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   movie_id  500 non-null    object
#  1   rank      500 non-null    int64
#  2   title     500 non-null    object
#  3   run_time  500 non-null    object
#  4   year      500 non-null    int64
#  5   rating    500 non-null    float64
#  6   votes     500 non-null    object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 27.5+ KB

# %%
# Cleaning and tranforming df2
 # rank, year, and votes should have a numeric integer data type.

#rank and year are already in int64 according to the top result
#converting votes to int
df2['votes']=df2['votes'].replace(',','',regex=True)
df2['votes']=df2['votes'].astype('int64')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   movie_id  500 non-null    object
#  1   rank      500 non-null    int64
#  2   title     500 non-null    object
#  3   run_time  500 non-null    object
#  4   year      500 non-null    int64
#  5   rating    500 non-null    float64
#  6   votes     500 non-null    int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 27.5+ KB

# %%
#converting runtime to minutes
# runtime column should be renamed to runtimeMinutes and the value should be in minutes, 
# for example: 2h 2m should be 122
df2['runtimeMinutes']=df2['run_time'].apply(lambda x: sum(int(num[:-1]) * (60 if 'h' in num else 1) for num in x.split()))
df2=df2.drop(columns=['run_time'])
print(df2)
# Out:
#       movie_id  rank                   title  year  rating    votes  \
# 0    tt7286456     1                   Joker  2019     8.4  1422218
# 1    tt4154796     2       Avengers: Endgame  2019     8.4  1227564
# 2    tt4154756     3  Avengers: Infinity War  2018     8.4  1167536
# 3    tt6751668     4                Parasite  2019     8.5   903939
# 4    tt1825683     5           Black Panther  2018     7.3   820837
# ..         ...   ...                     ...   ...     ...      ...
# 495  tt9072352   496                   Relic  2020     6.0    29282
# 496  tt1006569   497              Antebellum  2020     5.8    29199
# 497  tt8652728   498                   Waves  2019     7.5    29103
# 498  tt7748244   499            Mortal World  2018     7.6    29052
# 499  tt6768578   500                  Dogman  2018     7.2    28823
#
#      runtimeMinutes
# 0               122
# 1               181
# 2               149
# 3               132
# 4               134
# ..              ...
# 495              89
# 496             105
# 497             135
# 498             107
# 499             103
#
# [500 rows x 7 columns]

# %%
#check if the data types are according to the requirement
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   movie_id        500 non-null    object
#  1   rank            500 non-null    int64
#  2   title           500 non-null    object
#  3   year            500 non-null    int64
#  4   rating          500 non-null    float64
#  5   votes           500 non-null    int64
#  6   runtimeMinutes  500 non-null    int64
# dtypes: float64(1), int64(4), object(2)
# memory usage: 27.5+ KB

# %%
#check runtimeMinutes which is converted into minutes 
df2.head(20)
# Out:
#      movie_id  rank                                          title  year  \
# 0   tt7286456     1                                          Joker  2019
# 1   tt4154796     2                              Avengers: Endgame  2019
# 2   tt4154756     3                         Avengers: Infinity War  2018
# 3   tt6751668     4                                       Parasite  2019
# 4   tt1825683     5                                  Black Panther  2018
# 5   tt7131622     6                  Once Upon a Time in Hollywood  2019
# 6   tt8946378     7                                     Knives Out  2019
# 7   tt8579674     8                                           1917  2019
# 8   tt4633694     9              Spider-Man: Into the Spider-Verse  2018
# 9   tt5463162    10                                     Deadpool 2  2018
# 10  tt4154664    11                                 Captain Marvel  2019
# 11  tt1727824    12                              Bohemian Rhapsody  2018
# 12  tt6723592    13                                          Tenet  2020
# 13  tt6644200    14                                  A Quiet Place  2018
# 14  tt6966692    15                                     Green Book  2018
# 15  tt6320628    16                      Spider-Man: Far from Home  2019
# 16  tt1270797    17                                          Venom  2018
# 17  tt1477834    18                                        Aquaman  2018
# 18  tt2527338    19  Star Wars: Episode IX - The Rise of Skywalker  2019
# 19  tt1677720    20                               Ready Player One  2018
#
#     rating    votes  runtimeMinutes
# 0      8.4  1422218             122
# 1      8.4  1227564             181
# 2      8.4  1167536             149
# 3      8.5   903939             132
# 4      7.3   820837             134
# 5      7.6   809786             161
# 6      7.9   747547             130
# 7      8.2   650257             119
# 8      8.4   641118             117
# 9      7.6   624815             119
# 10     6.8   597379             123
# 11     7.9   574079             134
# 12     7.3   568337             150
# 13     7.5   567953              90
# 14     8.2   542702             130
# 15     7.4   537741             129
# 16     6.6   523643             112
# 17     6.8   505411             143
# 18     6.4   480882             141
# 19     7.4   468943             140

# %% [markdown]
# # 	Enrich the given dataset (df1) by merging it to the scraped data (df2).

# %%
# Merege the two dataframes to one dataframe called df bases on movied_id 
df=df1.merge(df2)

# %%
df
# Out:
#       movie_id                originalTitle  \
# 0    tt7286456                        Joker
# 1    tt4154796            Avengers: Endgame
# 2    tt4154756       Avengers: Infinity War
# 3    tt6751668                     Parasite
# 4    tt1825683                Black Panther
# ..         ...                          ...
# 495  tt9072352                        Relic
# 496  tt1006569  Episode dated 9 August 2005
# 497  tt8652728                        Waves
# 498  tt7748244                 Mortal World
# 499  tt6768578                       Dogman
#
#                                            description ratingCategory  \
# 0    During the 1980s, a failed stand-up comedian i...              R
# 1    After the devastating events of Avengers: Infi...          PG-13
# 2    The Avengers and their allies must be willing ...          PG-13
# 3    Greed and class discrimination threaten the ne...              R
# 4    T'Challa, heir to the hidden but advanced king...          PG-13
# ..                                                 ...            ...
# 495  A daughter, mother and grandmother are haunted...              R
# 496  Successful author Veronica Henley finds hersel...              R
# 497  Traces the journey of a suburban family - led ...              R
# 498  Mermer Family lives a double life working at t...              R
# 499  A timid dog groomer living in a poor suburb se...      Not Rated
#
#                       genres  rank                   title  year  rating  \
# 0       Crime,Drama,Thriller     1                   Joker  2019     8.4
# 1     Action,Adventure,Drama     2       Avengers: Endgame  2019     8.4
# 2    Action,Adventure,Sci-Fi     3  Avengers: Infinity War  2018     8.4
# 3             Drama,Thriller     4                Parasite  2019     8.5
# 4    Action,Adventure,Sci-Fi     5           Black Panther  2018     7.3
# ..                       ...   ...                     ...   ...     ...
# 495     Drama,Horror,Mystery   496                   Relic  2020     6.0
# 496                     News   497              Antebellum  2020     5.8
# 497      Drama,Romance,Sport   498                   Waves  2019     7.5
# 498      Action,Comedy,Crime   499            Mortal World  2018     7.6
# 499     Crime,Drama,Thriller   500                  Dogman  2018     7.2
#
#        votes  runtimeMinutes
# 0    1422218             122
# 1    1227564             181
# 2    1167536             149
# 3     903939             132
# 4     820837             134
# ..       ...             ...
# 495    29282              89
# 496    29199             105
# 497    29103             135
# 498    29052             107
# 499    28823             103
#
# [500 rows x 11 columns]

# %% [markdown]
# # Rearrange the dataset fields to be listed in the following order:
# movie_id , rank , title ,  originalTitle ,  description ,
#           year ,  votes , rating ,  runtimeMinutes ,  ratingCategory ,  genres

# %%
# Rearrange the dataset fields as suggested.
df=df[['movie_id','rank','title','originalTitle','description','year','votes','rating','runtimeMinutes','ratingCategory','genres']]

# %%
#Check if it is rearranged
df
# Out:
#       movie_id  rank                   title                originalTitle  \
# 0    tt7286456     1                   Joker                        Joker
# 1    tt4154796     2       Avengers: Endgame            Avengers: Endgame
# 2    tt4154756     3  Avengers: Infinity War       Avengers: Infinity War
# 3    tt6751668     4                Parasite                     Parasite
# 4    tt1825683     5           Black Panther                Black Panther
# ..         ...   ...                     ...                          ...
# 495  tt9072352   496                   Relic                        Relic
# 496  tt1006569   497              Antebellum  Episode dated 9 August 2005
# 497  tt8652728   498                   Waves                        Waves
# 498  tt7748244   499            Mortal World                 Mortal World
# 499  tt6768578   500                  Dogman                       Dogman
#
#                                            description  year    votes  rating  \
# 0    During the 1980s, a failed stand-up comedian i...  2019  1422218     8.4
# 1    After the devastating events of Avengers: Infi...  2019  1227564     8.4
# 2    The Avengers and their allies must be willing ...  2018  1167536     8.4
# 3    Greed and class discrimination threaten the ne...  2019   903939     8.5
# 4    T'Challa, heir to the hidden but advanced king...  2018   820837     7.3
# ..                                                 ...   ...      ...     ...
# 495  A daughter, mother and grandmother are haunted...  2020    29282     6.0
# 496  Successful author Veronica Henley finds hersel...  2020    29199     5.8
# 497  Traces the journey of a suburban family - led ...  2019    29103     7.5
# 498  Mermer Family lives a double life working at t...  2018    29052     7.6
# 499  A timid dog groomer living in a poor suburb se...  2018    28823     7.2
#
#      runtimeMinutes ratingCategory                   genres
# 0               122              R     Crime,Drama,Thriller
# 1               181          PG-13   Action,Adventure,Drama
# 2               149          PG-13  Action,Adventure,Sci-Fi
# 3               132              R           Drama,Thriller
# 4               134          PG-13  Action,Adventure,Sci-Fi
# ..              ...            ...                      ...
# 495              89              R     Drama,Horror,Mystery
# 496             105              R                     News
# 497             135              R      Drama,Romance,Sport
# 498             107              R      Action,Comedy,Crime
# 499             103      Not Rated     Crime,Drama,Thriller
#
# [500 rows x 11 columns]

# %% [markdown]
# # Export the enriched dataset to a CSV file:

# %%
# Use the following naming convention: 
#  Project_3_PartA_Lastname.csv
df.to_csv('Project_3_PartA.csv', index = False,encoding="cp1252")

# %% [markdown]
# # Summary

# %% [markdown]
#     Step 1: Scraped the required data from the IDMb website.
#     Step 2: Convert the movies list of dicts to dataframe.
#     Step 3: Exported the collected movies to IMDb_TopVoted.csv file.
#     Step 4: Imported the movies.csv file to df1 and print df1.
#     Step 5: Found empty values in ratingCategory and filled it with 'Not Rated'
#     Step 6: Replaced 'Unrated' to 'Not Rated' to have uniform data in ratingCategory field
#     Step 7: Replaced "\N" with - to make it more meaningful
#     Step 8: Imported the scraped data from the IMDb_TopVoted.csv file to Pandas DataFrame called df2
#     Step 9: Performed Data cleansing and transformation for df2:
#         - corrected the data types
#         - converted the runtime to minutes and renamed the column
#     Step 10: Merged the datasets.
#     Step 11: Rearranged the dataset fields as suggested.
#     Step 12: Exported the enriched dataset to a CSV file.
